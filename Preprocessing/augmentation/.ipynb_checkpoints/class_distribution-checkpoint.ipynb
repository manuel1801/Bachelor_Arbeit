# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os
import sys

# %% [markdown]
# ### Pandas Dataframes aus train.csv file erzeugen

# %%
train_csv = os.path.join(os.getcwd(), 'train.csv')
train_aug_csv = os.path.join(os.getcwd(), 'train_aug.csv')

assert os.path.isfile(train_csv)
assert os.path.isfile(train_aug_csv)
           
df_train = pd.read_csv(train_csv)
df_train_aug = pd.read_csv(train_aug_csv)

# %% [markdown]
# ### Verteilung für train.csv anzeigen (nicht augmentiert)

# %%
f = df_train['class'].value_counts().plot(kind='bar')

# %% [markdown]
# ### Verteilung für train.csv anzeigen (augmentiert)

# %%
df_train_aug['class'].value_counts().plot(kind='bar')
