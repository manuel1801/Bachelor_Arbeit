# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os

# %%
workspace = '/home/manuel/Bachelor_Arbeit/TensorFlow/workspace/'
datasets = ['OI_Animals',
            'OI_Animals_Augmented',
            'Beispiel_Set',
            'ToyExample']

train_csv = os.path.join(workspace, 'OI_Animals_9/train.csv')
train_aug_csv = os.path.join(workspace, 'OI_Animals_LessAug_9_3000/train.csv')

assert os.path.isfile(train_csv)
assert os.path.isfile(train_aug_csv)

           
df_train = pd.read_csv(train_csv)
df_train_aug = pd.read_csv(train_aug_csv)

# %%
f = df_train['class'].value_counts().plot(kind='bar')

# %%
df_train_aug['class'].value_counts().plot(kind='bar')
