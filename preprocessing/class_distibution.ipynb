# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
workspace = '/home/manuel/Bachelor_Arbeit/TensorFlow/workspace/'
datasets = ['OI_Animals',
            'OI_Animals_Augmented',
            'Beispiel_Set',
            'ToyExample']
           
df_train = pd.read_csv(workspace  + datasets[0] + '/train.csv')
df_test = pd.read_csv(workspace  + datasets[0] + '/test.csv')
 

df_train_aug = pd.read_csv(workspace  + datasets[1] + '/train.csv')
df_test_aug = pd.read_csv(workspace  + datasets[1] + '/test.csv')

# %%
df_train['class'].value_counts().plot(kind='bar')

# %%
df_train_aug['class'].value_counts().plot(kind='bar')
