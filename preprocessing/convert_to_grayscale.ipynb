# %%
import cv2
import os
import sys
from matplotlib import pyplot as plt

# %%
img_dir = 'train_sample_for_aug_gray/train/Banana/'
img_paths = [img_dir + img for img in os.listdir(img_dir) if img[-3:] == 'jpg']
img_paths
# Out:
# ['train_sample_for_aug_gray/train/Banana/0b3691c7f10c1d08.jpg',
#  'train_sample_for_aug_gray/train/Banana/00ac03de349a3c5b.jpg',
#  'train_sample_for_aug_gray/train/Banana/0b66e3789abf7b68.jpg',
#  'train_sample_for_aug_gray/train/Banana/0a292a0d2069fd51.jpg',
#  'train_sample_for_aug_gray/train/Banana/0a7e071b30e23d13.jpg',
#  'train_sample_for_aug_gray/train/Banana/0b71c3eac5c786b9.jpg',
#  'train_sample_for_aug_gray/train/Banana/0b8171f866ca02b2.jpg',
#  'train_sample_for_aug_gray/train/Banana/0a99cba28b9cd5f0.jpg',
#  'train_sample_for_aug_gray/train/Banana/0b2eecd9dabc3441.jpg',
#  'train_sample_for_aug_gray/train/Banana/0b6c95f4c4e51391.jpg']

# %%
i = 1
img = cv2.imread(img_paths[i])
plt.imshow(img)
img.shape
# Out:
# (683, 1024, 3)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img.shape
#plt.imshow(img)
img.shape
# Out:
# (683, 1024)
